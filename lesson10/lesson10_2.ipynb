# %% [markdown]
# # python如何讀取students.csv
# 你可以使用 Python 內建的 csv 模組來讀取 students.csv，以下是簡單的範例：
#
# import csv
#
# with open('students.csv', newline='', encoding='utf-8') as csvfile:
#     reader = csv.DictReader(csvfile)  # 使用 DictReader 讀取成字典格式
#     for row in reader:
#         print(row)  # 每一列會是字典，鍵是欄位名稱
# 說明：
#
#  - open() 中指定 encoding='utf-8' 避免中文亂碼。
#  - csv.DictReader 會自動把 CSV 第一列當作欄位名稱，並將每列轉成字典。
#  - 你也可以用 csv.reader 讀成串列形式，但 DictReader 更適合有欄位標題的 CSV。
# 執行後，每一列會輸出類似：
#
# {'姓名': '錢欣潔', '國文': '100', '英文': '77', '數學': '59'}
# {'姓名': '許芳如', '國文': '98', '英文': '74', '數學': '99'}
# {'姓名': '陳怡伶', '國文': '54', '英文': '67', '數學': '79'}
# 這是讀取 CSV 檔案並取得每筆資料的標準作法[1][2][4][5]。

# %%
import csv
from csv import DictReader

with open('students.csv',encoding='utf-8',newline='') as csv_file:
    reader:DictReader = csv.DictReader(csv_file)
    students = list(reader)
    
students
# Out:
# [{'姓名': '楊又源', '國文': '55', '英文': '67', '數學': '59'},
#  {'姓名': '張雅芬', '國文': '83', '英文': '74', '數學': '93'},
#  {'姓名': '白美珍', '國文': '51', '英文': '57', '數學': '82'},
#  {'姓名': '黎惠雯', '國文': '72', '英文': '94', '數學': '82'},
#  {'姓名': '鄧亭聿', '國文': '86', '英文': '65', '數學': '61'},
#  {'姓名': '洪阿惠', '國文': '97', '英文': '54', '數學': '92'},
#  {'姓名': '游一鈺', '國文': '63', '英文': '66', '數學': '86'},
#  {'姓名': '張軒宸', '國文': '99', '英文': '62', '數學': '75'},
#  {'姓名': '沈心利', '國文': '86', '英文': '60', '數學': '63'},
#  {'姓名': '鄭淑珍', '國文': '55', '英文': '96', '數學': '90'},
#  {'姓名': '楊偉翔', '國文': '100', '英文': '84', '數學': '85'},
#  {'姓名': '黃必琪', '國文': '89', '英文': '88', '數學': '59'},
#  {'姓名': '林益妏', '國文': '95', '英文': '51', '數學': '93'},
#  {'姓名': '馮淑芬', '國文': '65', '英文': '94', '數學': '50'},
#  {'姓名': '吳昕婷', '國文': '89', '英文': '59', '數學': '79'},
#  {'姓名': '周琬婷', '國文': '94', '英文': '54', '數學': '59'},
#  {'姓名': '楊少亮', '國文': '98', '英文': '97', '數學': '98'},
#  {'姓名': '陳倩潔', '國文': '74', '英文': '100', '數學': '99'},
#  {'姓名': '鄭孟芳', '國文': '82', '英文': '51', '數學': '89'},
#  {'姓名': '林建勳', '國文': '62', '英文': '56', '數學': '87'},
#  {'姓名': '林詠斌', '國文': '74', '英文': '73', '數學': '92'},
#  {'姓名': '黃佩芬', '國文': '59', '英文': '78', '數學': '95'},
#  {'姓名': '錢佩豪', '國文': '80', '英文': '92', '數學': '100'},
#  {'姓名': '王泓泰', '國文': '79', '英文': '94', '數學': '90'},
#  {'姓名': '陳逸華', '國文': '56', '英文': '61', '數學': '55'},
#  {'姓名': '柯宜臻', '國文': '52', '英文': '87', '數學': '95'},
#  {'姓名': '蘇婷婷', '國文': '61', '英文': '96', '數學': '82'},
#  {'姓名': '蔡嘉音', '國文': '85', '英文': '95', '數學': '54'},
#  {'姓名': '黃麗美', '國文': '93', '英文': '91', '數學': '86'},
#  {'姓名': '陳彥治', '國文': '52', '英文': '77', '數學': '62'},
#  {'姓名': '彭虹屏', '國文': '91', '英文': '100', '數學': '95'},
#  {'姓名': '陳建香', '國文': '95', '英文': '66', '數學': '65'},
#  {'姓名': '謝佳穎', '國文': '64', '英文': '89', '數學': '63'},
#  {'姓名': '郎慧萍', '國文': '69', '英文': '100', '數學': '58'},
#  {'姓名': '黃旻林', '國文': '77', '英文': '52', '數學': '87'},
#  {'姓名': '趙宛真', '國文': '91', '英文': '87', '數學': '52'},
#  {'姓名': '胡芳瑜', '國文': '62', '英文': '56', '數學': '83'},
#  {'姓名': '楊韻如', '國文': '86', '英文': '85', '數學': '84'},
#  {'姓名': '陳逸凡', '國文': '71', '英文': '90', '數學': '73'},
#  {'姓名': '景歡燦', '國文': '81', '英文': '61', '數學': '68'},
#  {'姓名': '謝貞妃', '國文': '98', '英文': '97', '數學': '96'},
#  {'姓名': '李政白', '國文': '58', '英文': '96', '數學': '52'},
#  {'姓名': '陳建豪', '國文': '64', '英文': '69', '數學': '68'},
#  {'姓名': '林玉佩', '國文': '65', '英文': '70', '數學': '63'},
#  {'姓名': '盧冠發', '國文': '73', '英文': '81', '數學': '83'},
#  {'姓名': '羅幸娥', '國文': '89', '英文': '83', '數學': '82'},
#  {'姓名': '潘英迪', '國文': '68', '英文': '69', '數學': '96'},
#  {'姓名': '陳倩妮', '國文': '80', '英文': '65', '數學': '93'},
#  {'姓名': '孫火清', '國文': '99', '英文': '75', '數學': '96'},
#  {'姓名': '李慶亮', '國文': '93', '英文': '55', '數學': '76'}]
